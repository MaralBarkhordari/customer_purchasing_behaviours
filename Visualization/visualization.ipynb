# %%
import pandas as pd


file_path = r'C:\Users\Beast\customer_purchasing_behaviours\processed\processed_dataset.csv'
df = pd.read_csv(file_path)

print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 238 non-null    float64
#  1   annual_income       238 non-null    float64
#  2   purchase_amount     238 non-null    float64
#  3   loyalty_score       238 non-null    float64
#  4   purchase_frequency  238 non-null    float64
#  5   region_East         238 non-null    float64
#  6   region_North        238 non-null    float64
#  7   region_South        238 non-null    float64
#  8   region_West         238 non-null    float64
# dtypes: float64(9)
# memory usage: 16.9 KB
# None
#                 age  annual_income  purchase_amount  loyalty_score  \
# count  2.380000e+02   2.380000e+02     2.380000e+02   2.380000e+02
# mean  -3.097429e-16   1.977876e-16     1.194189e-16   1.492737e-17
# std    1.002107e+00   1.002107e+00     1.002107e+00   1.002107e+00
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['annual_income'], bins=30, kde=True)
plt.title('Annual Income Distribution')
plt.xlabel('Annual Income (Standardized)')
plt.ylabel('Frequency')
plt.show()

# %%
# Joint Plot for Annual Income and Loyalty Score
plt.figure(figsize=(10, 10))
sns.jointplot(x='annual_income', y='loyalty_score', data=df, kind='hex', cmap='Blues')
plt.suptitle('Joint Plot of Annual Income vs Loyalty Score', y=1.02, fontsize=16)
plt.show()

# %%
# Checking if there are any non-numeric or NaN values in numerical columns
invalid_values_summary = df[['age', 'annual_income', 'purchase_amount', 'loyalty_score', 'purchase_frequency']].apply(lambda x: pd.to_numeric(x, errors='coerce')).isna().sum()

# Displaying the count of invalid values in each column
invalid_values_summary
# Out:
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# purchase_frequency    0
# dtype: int64

# %%
# Set seaborn style for better aesthetics
sns.set(style="whitegrid", palette="muted")

# %%
df['region'] = df[['region_North', 'region_South', 'region_East', 'region_West']].idxmax(axis=1).str.replace('region_', '')


print(df['region'].unique())
# Out:
# ['North' 'South' 'West' 'East']

# %%
# Scatter Plot 1: Age vs Annual Income Colored by Region
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='annual_income', hue='region', data=df, palette='Set1')
plt.title('Scatter Plot: Age vs Annual Income Colored by Region', fontsize=16)
plt.xlabel('Age (Standardized)')
plt.ylabel('Annual Income (Standardized)')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.show()

# %%
# Scatter Plot 1: Age vs Annual Income Colored by Region
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='annual_income', hue='region', data=df, palette='Set1')
plt.title('Scatter Plot: Age vs Annual Income Colored by Region', fontsize=16)
plt.xlabel('Age (Standardized)')
plt.ylabel('Annual Income (Standardized)')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.show()

# %%
# Scatter Plot 1: Age vs Annual Income Colored by Region
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='annual_income', hue='region', data=df, palette='Set1')
plt.title('Scatter Plot: Age vs Annual Income Colored by Region', fontsize=16)
plt.xlabel('Age (Standardized)')
plt.ylabel('Annual Income (Standardized)')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# Insights drawn from the individual scatter plots visualizing the relationships between selected features:
#
# Scatter Plot: Age vs Annual Income Colored by Region:
#
# This plot shows the relationship between age and annual income, with colors representing different customer regions. It reveals the distribution of customers across various regions, indicating trends between age and income. For example, we can see whether certain age groups tend to have higher incomes and how this distribution varies by region.
# Scatter Plot: Loyalty Score vs Purchase Amount Colored by Region:
#
# This visualization helps in understanding how customer loyalty is correlated with their purchase amount, with data segmented by different regions. It allows us to see if customers with higher loyalty scores are also the ones making larger purchases, and if there are regional differences in this trend.
# Scatter Plot: Annual Income vs Purchase Frequency Colored by Region:
#
# This scatter plot provides insights into how annual income affects purchase frequency, with each point color-coded based on the customer’s region. It allows us to identify patterns such as whether customers with higher incomes tend to purchase more frequently and how these relationships might differ from region to region.
